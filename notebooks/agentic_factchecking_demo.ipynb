# %% [markdown]
# # Agentic Automated Fact-Checking Demo
#
# This notebook demonstrates a **real** agentic fact-checking pipeline using **real APIs**:
#
# - Claim → Claim Understanding → Retrieval ↔ Evaluation Loop → Verdict → Explanation
# - Inspired by Anthropic's "Building Effective Agents" patterns.
#
# **Requirements:**
# - `OPENAI_API_KEY` or `ANTHROPIC_API_KEY` (required)
# - `GOOGLE_SEARCH_API_KEY` and `GOOGLE_SEARCH_ENGINE_ID` (optional, for web search)
#
# **Note:** This uses real APIs - no dummies or static data!

# %% [markdown]
# ## Setup
#
# Install (editable) and ensure the project is on the Python path. If you've already installed locally, you can skip the install cell.

# %%
# %pip install pydantic==2.7.0 python-dotenv
# Out:
# Requirement already satisfied: pydantic==2.7.0 in /Users/ghadir/AFC/.venv/lib/python3.12/site-packages (2.7.0)
# Requirement already satisfied: python-dotenv in /Users/ghadir/AFC/.venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/ghadir/AFC/.venv/lib/python3.12/site-packages (from pydantic==2.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /Users/ghadir/AFC/.venv/lib/python3.12/site-packages (from pydantic==2.7.0) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/ghadir/AFC/.venv/lib/python3.12/site-packages (from pydantic==2.7.0) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -e
# Out:
# Usage:
#   /Users/ghadir/AFC/.venv/bin/python3 -m pip install [options] <requirement specifier> [package-index-options] ...
#   /Users/ghadir/AFC/.venv/bin/python3 -m pip install [options] -r <requirements file> [package-index-options] ...
#   /Users/ghadir/AFC/.venv/bin/python3 -m pip install [options] [-e] <vcs project url> ...
#   /Users/ghadir/AFC/.venv/bin/python3 -m pip install [options] [-e] <local project path> ...
#   /Users/ghadir/AFC/.venv/bin/python3 -m pip install [options] <archive url/path> ...
#
# -e option requires 1 argument
# Note: you may need to restart the kernel to use updated packages.

# %%
# Ensure src/ is on the path for this notebook environment
import sys
import pathlib

ROOT = pathlib.Path("..").resolve()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

print("Using project root:", ROOT)
# Out:
# Using project root: /Users/ghadir/AFC

# %%
from factcheck_agent.llm_client import get_default_llm_client
from factcheck_agent.pipeline import FactCheckingPipeline
from factcheck_agent.agents.retrieval import RetrievalAgent
from factcheck_agent.models import Claim
from factcheck_agent.config import get_config

# Get real LLM (will fail if no API key - no dummies!)
try:
    llm = get_default_llm_client(use_dummy_if_missing_key=False)
    print(f"✅ Using LLM: {type(llm).__name__}")
except RuntimeError as e:
    print(f"❌ Error: {e}")
    print("\nPlease set OPENAI_API_KEY or ANTHROPIC_API_KEY in your environment or .env file.")
    raise

# Check Google Search configuration
config = get_config()
has_google_search = bool(
    getattr(config, "GOOGLE_SEARCH_API_KEY", None) 
    and getattr(config, "GOOGLE_SEARCH_ENGINE_ID", None)
)

if has_google_search:
    # Use real Google Search retrieval
    retrieval_agent = RetrievalAgent(llm=llm)
    print("✅ Using Google Search for evidence retrieval")
else:
    print("⚠️  Google Search not configured - using LLM-only retrieval")
    print("   Set GOOGLE_SEARCH_API_KEY and GOOGLE_SEARCH_ENGINE_ID for web search")
    # Create a retrieval agent without Google Search (will use LLM to generate queries but won't search)
    retrieval_agent = RetrievalAgent(llm=llm)

# Create pipeline with real APIs
pipeline = FactCheckingPipeline(llm=llm, retrieval_agent=retrieval_agent)
print("\n🚀 Pipeline ready with real APIs!")
print("   - LLM: Real API")
print("   - Retrieval: Google Search" if has_google_search else "   - Retrieval: LLM-only (no web search)")
# Out:
# ✅ Using LLM: OpenAILLMClient
# ✅ Using Google Search for evidence retrieval
#
# 🚀 Pipeline ready with real APIs!
#    - LLM: Real API
#    - Retrieval: Google Search

# %% [markdown]
# ## Run example claims
#
# You can either:
# 1. Use the full pipeline (recommended) - runs everything automatically
# 2. Run step-by-step to see intermediate results
# 3. **NEW:** Detect claims from long text and fact-check each one (see cells below)
#
# **Note:** This notebook now uses **real APIs** - no dummies or static data!
# - Real LLM for reasoning and explanations
# - Real Google Search for evidence retrieval (if configured)
# - Real claim detection from articles/posts

# %%
# Option 1: Use the full pipeline (simplest - recommended)
# Updated to accept single claim (str or Claim) or multiple claims (list)
async def fact_check_full(claims):
    """
    Run the full pipeline and display results.
    
    Args:
        claims: Can be:
            - A single string (claim text)
            - A single Claim object
            - A single DetectedClaim object
            - A list of any of the above
    
    Returns:
        List of FactCheckResult objects (or single result if single claim provided)
    """
    from factcheck_agent.models import DetectedClaim
    
    # Normalize input to a list
    if isinstance(claims, str):
        # Single string - create a Claim
        claim_list = [Claim(id="claim-0", raw_text=claims)]
        single_result = True
    elif isinstance(claims, Claim):
        claim_list = [claims]
        single_result = True
    elif isinstance(claims, DetectedClaim):
        # Convert DetectedClaim to Claim
        claim_list = [Claim(
            id=claims.id,
            raw_text=claims.raw_text,
            metadata={
                **(claims.metadata or {}),
                "importance": str(claims.importance) if claims.importance is not None else None,
                "sentence_index": str(claims.sentence_index) if claims.sentence_index is not None else None,
            }
        )]
        single_result = True
    elif isinstance(claims, list):
        # List of claims - convert each to Claim
        claim_list = []
        for i, item in enumerate(claims):
            if isinstance(item, str):
                claim_list.append(Claim(id=f"claim-{i}", raw_text=item))
            elif isinstance(item, Claim):
                claim_list.append(item)
            elif isinstance(item, DetectedClaim):
                claim_list.append(Claim(
                    id=item.id,
                    raw_text=item.raw_text,
                    metadata={
                        **(item.metadata or {}),
                        "importance": str(item.importance) if item.importance is not None else None,
                        "sentence_index": str(item.sentence_index) if item.sentence_index is not None else None,
                    }
                ))
        single_result = False
    else:
        raise ValueError(f"Unsupported claim type: {type(claims)}")
    
    results = []
    
    for i, claim in enumerate(claim_list, 1):
        if len(claim_list) > 1:
            print("=" * 80)
            print(f"🔍 Fact-checking claim {i}/{len(claim_list)}: {claim.raw_text[:80]}...")
            print("=" * 80)
        else:
            print("=" * 80)
            print(f"🔍 Fact-checking: {claim.raw_text}")
            print("=" * 80)
        
        print("\n⏳ Processing... This may take 30-60 seconds...\n")
        
        # Use LLM normalization if available
        if pipeline.claim_understanding.llm:
            try:
                claim = await pipeline.claim_understanding.normalize_claim_llm(claim)
            except Exception:
                # Fallback to basic normalization
                claim = pipeline.claim_understanding.normalize_claim(claim)
        else:
            claim = pipeline.claim_understanding.normalize_claim(claim)
        
        result = await pipeline.process(claim)
        results.append(result)
        
        print("=" * 80)
        print("✅ RESULTS")
        print("=" * 80)
        print(f"\n📊 Verdict: {result.verdict.label}")
        print(f"🎯 Confidence: {result.verdict.confidence:.0%}")
        
        if result.verdict.reasoning:
            print(f"\n🧠 Reasoning: {result.verdict.reasoning}")
        
        print(f"\n💭 Explanation:\n{result.explanation}\n")
        
        if result.evidence:
            print(f"📚 Evidence ({len(result.evidence)} snippet(s)):")
            print("-" * 80)
            for j, e in enumerate(result.evidence[:5], 1):  # Show first 5
                title = e.metadata.get('title', 'No title') if e.metadata else 'No title'
                url = e.metadata.get('url', '') if e.metadata else ''
                print(f"\n[{j}] {title}")
                if url:
                    print(f"    🔗 {url}")
                print(f"    source: {e.source}")
                preview = e.text[:200] + "..." if len(e.text) > 200 else e.text
                print(f"    📄 {preview}")
        else:
            print("📚 No evidence retrieved")
        
        print("\n" + "=" * 80 + "\n")
    
    # Return single result if single claim was provided, otherwise return list
    return results[0] if single_result else results


# Example: Fact-check a single claim
# await fact_check_full("Saudi Arabia is the largest oil producer in the world.")


# Option 2: Step-by-step (see intermediate results)
async def run_demo_step_by_step(text: str):
    """Run step-by-step to see intermediate results."""
    claim = Claim(id="demo-" + text[:8].replace(" ", "_"), raw_text=text)

    # Stage 1: Normalize
    normalized = pipeline.claim_understanding.normalize_claim(claim)
    print("📝 Normalized claim:", normalized.normalized_text)

    # Stage 2: Retrieval (async)
    print("\n🔍 Retrieving evidence...")
    candidates = await pipeline.retrieval.retrieve_evidence(normalized)
    print(f"   Found {len(candidates)} candidate(s):")
    for e in candidates[:3]:  # Show first 3
        preview = e.text[:100] + ("..." if len(e.text) > 100 else "")
        title = e.metadata.get('title', '') if e.metadata else ''
        print(f"   - [{e.source}] {title}")
        print(f"     {preview}")

    # Selection
    selected = pipeline.evidence_selection.select(normalized, candidates, k=5)

    # Evaluation (async)
    print("\n📊 Evaluating evidence...")
    evaluation = await pipeline.evidence_evaluation.evaluate(normalized, selected)
    print(f"   Sufficient: {evaluation.sufficient}")
    print(f"   Confidence: {evaluation.confidence:.0%}")
    if evaluation.notes:
        print(f"   Notes: {evaluation.notes}")

    # Reasoning & verdict (async)
    print("\n🤔 Generating verdict...")
    verdict = await pipeline.reasoning_and_verdict.decide(normalized, evaluation.selected_evidence)
    explanation = await pipeline.explanation.generate(normalized, verdict, evaluation.selected_evidence)

    print(f"\n✅ Verdict: {verdict.label}")
    print(f"🎯 Confidence: {verdict.confidence:.0%}")
    print(f"\n💭 Explanation:\n{explanation}\n")

article = """
In 2020, Saudi Arabia officially launched its National Strategy for Data and Artificial Intelligence (NSDAI) as part of Vision 2030. The strategy aims to position the Kingdom as a global leader in artificial intelligence by 2030, focusing on innovation, talent development, and the use of AI to improve quality of life and government efficiency.

The plan includes training more than 20,000 AI and data specialists, attracting leading global companies, and establishing partnerships with international research institutions. Saudi Arabia has already invested in several AI-driven projects, such as NEOM, The Line city, and smart government initiatives that use data analytics to optimize urban planning and resource management.

The Saudi Data and Artificial Intelligence Authority (SDAIA) oversees the implementation of this strategy, working closely with the Ministry of Communications and Information Technology (MCIT) to ensure the ethical and secure use of AI technologies. The government also hosted the Global AI Summit in Riyadh, bringing together experts from around the world to discuss the future of artificial intelligence and the role of emerging technologies in sustainable development.

Recently, several media outlets reported that Saudi Arabia announced plans to ban the use of foreign AI tools by 2025 to promote locally developed systems. However, no official Saudi source has confirmed such an announcement, and the claim appears to be false or misleading, as the country continues to collaborate internationally in the field of artificial intelligence.
"""


# Example usage (commented out):
# await fact_check_full("Saudi Arabia is the largest oil producer in the world.")
# await fact_check_full(["Claim 1", "Claim 2"])  # Multiple claims

# %% [markdown]
# ## NEW: Claim Detection from Long Text
#
# **Workflow:**
# 1. **Provide your article** (cell below)
# 2. **Detect claims** from the article
# 3. **Fact-check all detected claims** automatically
#
# This workflow is perfect for analyzing news articles, social media posts, or any long text!

# %%
### Step 1: Provide your article

Edit the `article` variable below with your text, or paste an article from a news source, social media post, etc.
# Out:
#   Cell In[8], line 3
#     Edit the `article` variable below with your text, or paste an article from a news source, social media post, etc.
#          ^
# SyntaxError: invalid syntax

# %%
# Paste or type your article here
article = """
Saudi Arabia announced plans to invest $100 billion in renewable energy by 2030, 
according to a statement from the Ministry of Energy. The country, which is currently 
the world's largest oil producer, aims to diversify its energy sources and reduce 
carbon emissions. Climate experts have praised the initiative, noting that it represents 
a significant shift in the country's energy policy. The investment will focus on solar 
and wind power projects across the kingdom. Some analysts believe this move could 
transform the global energy market. The announcement came during a climate summit 
in Riyadh, where officials also revealed plans to achieve net-zero emissions by 2060.
"""

print("📄 Your Article:")
print("=" * 80)
print(article.strip())
print("=" * 80)
print(f"\n📊 Article length: {len(article)} characters")
# Out:
# 📄 Your Article:
# ================================================================================
# Saudi Arabia announced plans to invest $100 billion in renewable energy by 2030,
# according to a statement from the Ministry of Energy. The country, which is currently
# the world's largest oil producer, aims to diversify its energy sources and reduce
# carbon emissions. Climate experts have praised the initiative, noting that it represents
# a significant shift in the country's energy policy. The investment will focus on solar
# and wind power projects across the kingdom. Some analysts believe this move could
# transform the global energy market. The announcement came during a climate summit
# in Riyadh, where officials also revealed plans to achieve net-zero emissions by 2060.
# ================================================================================
#
# 📊 Article length: 683 characters

# %% [markdown]
# ### Step 2: Detect check-worthy claims

# %%
from factcheck_agent.agents.claim_understanding import ClaimUnderstandingAgent

# Create claim understanding agent (uses the same LLM as pipeline)
claim_agent = ClaimUnderstandingAgent(llm=llm)

print("🔍 Detecting check-worthy claims from your article...\n")

# Detect claims from the text
# min_importance: only include claims with importance >= 0.5 (adjust as needed)
detected_claims = await claim_agent.detect_claims(article, min_importance=0.5)

print(f"✅ Detected {len(detected_claims)} check-worthy claim(s):\n")
for i, claim in enumerate(detected_claims, 1):
    print(f"[{i}] {claim.raw_text}")
    print(f"    📊 Importance: {claim.importance:.0%}")
    if claim.sentence_index is not None:
        print(f"    📍 Sentence: {claim.sentence_index}")
    print()

if not detected_claims:
    print("⚠️  No claims detected. Try:")
    print("   - Lowering min_importance (e.g., 0.3)")
    print("   - Checking if the text contains factual claims")
    print("   - Making sure the text is long enough")
# Out:
# 🔍 Detecting check-worthy claims from your article...
#
# ✅ Detected 4 check-worthy claim(s):
#
# [1] Saudi Arabia announced plans to invest $100 billion in renewable energy by 2030, according to a statement from the Ministry of Energy.
#     📊 Importance: 100%
#     📍 Sentence: 0
#
# [2] The announcement came during a climate summit in Riyadh, where officials also revealed plans to achieve net-zero emissions by 2060.
#     📊 Importance: 100%
#     📍 Sentence: 6
#
# [3] The country, which is currently the world's largest oil producer, aims to diversify its energy sources and reduce carbon emissions.
#     📊 Importance: 90%
#     📍 Sentence: 1
#
# [4] The investment will focus on solar and wind power projects across the kingdom.
#     📊 Importance: 80%
#     📍 Sentence: 4

# %% [markdown]
# ### Step 3: Fact-check all detected claims
#
# The `fact_check_full()` function will automatically fact-check all detected claims!

# %%
# Fact-check all detected claims automatically!
if detected_claims:
    print("🚀 Starting fact-checking for all detected claims...\n")
    results = await fact_check_full(detected_claims)
    
    # Summary
    print("\n" + "=" * 80)
    print("📊 SUMMARY")
    print("=" * 80)
    print(f"\nTotal claims detected: {len(detected_claims)}")
    print(f"Successfully fact-checked: {len(results) if isinstance(results, list) else 1}\n")
    
    print("Results by importance:")
    if isinstance(results, list):
        for dc, result in zip(detected_claims, results):
            verdict_emoji = "✅" if result.verdict.label == "SUPPORTS" else "❌" if result.verdict.label == "REFUTES" else "⚠️"
            print(f"  {verdict_emoji} [{dc.importance:.0%}] {dc.raw_text[:60]}... → {result.verdict.label} ({result.verdict.confidence:.0%})")
    else:
        dc = detected_claims[0]
        verdict_emoji = "✅" if results.verdict.label == "SUPPORTS" else "❌" if results.verdict.label == "REFUTES" else "⚠️"
        print(f"  {verdict_emoji} [{dc.importance:.0%}] {dc.raw_text[:60]}... → {results.verdict.label} ({results.verdict.confidence:.0%})")
else:
    print("⚠️  No claims to fact-check. Run the detection cell above first.")
# Out:
# 🚀 Starting fact-checking for all detected claims...
#
# ================================================================================
# 🔍 Fact-checking claim 1/4: Saudi Arabia announced plans to invest $100 billion in renewable energy by 2030,...
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: NOT_ENOUGH_INFO
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: The evidence mentions Saudi Arabia's renewable energy targets and investments, including plans to increase renewable energy capacity to 130 GW by 2030 and some investment figures, but none explicitly confirm that Saudi Arabia announced plans to invest $100 billion in renewable energy by 2030 according to a statement from the Ministry of Energy. There is no direct mention of the $100 billion figure or a statement from the Ministry of Energy in the evidence provided.
#
# 💭 Explanation:
# The verdict is NOT_ENOUGH_INFO. While the evidence shows that Saudi Arabia has ambitious renewable energy targets and some investment commitments, there is no direct confirmation of a $100 billion investment plan announced by the Ministry of Energy. Without a clear statement or source explicitly linking the $100 billion figure to an official announcement from the Ministry of Energy, the claim cannot be fully verified.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] Information About Saudi Green Initiative
#     🔗 https://www.sgi.gov.sa/about-sgi/
#     source: google-search
#     📄 Inaugurated in 2021, SGI unites environmental protection, energy transition and sustainability programs with the overarching aims of offsetting and reducing ...
#
# [2] 2025 Saudi Arabia Investment Climate Statement
#     🔗 https://www.state.gov/wp-content/uploads/2025/09/638719_2025-Saudi-Arabia-Investment-Climate-Statement.pdf
#     source: google-search
#     📄 • Ministry of Energy, Saudi Aramco (Saudi Arabian Oil Company), and. • Gulf ... Saudi government and companies which commit to invest a minimum of $5.2 billion by ...
#
# [3] Public Investment Fund: PIF | Home
#     🔗 https://www.pif.gov.sa/en/
#     source: google-search
#     📄 PIF is a global and domestic investor. As one of the world's largest sovereign wealth funds, PIF is a key driver of Saudi Vision 2030, with HRH Crown Prince ...
#
# [4] Saudi Arabia pushes ahead with economic transformation, minister ...
#     🔗 https://www.reuters.com/world/middle-east/saudi-arabia-doubling-down-economic-transformation-plan-finance-minister-says-2024-10-30/
#     source: google-search
#     📄 Oct 30, 2024 ... ... Investment Initiative (FII) in Riyadh, Saudi Arabia October 30, 2024. ... green energy. He previously covered Gulf financial and economic news ...
#
# [5] Progress Report on President Biden's Climate Finance Pledge ...
#     🔗 https://2021-2025.state.gov/progress-report-on-president-bidens-climate-finance-pledge/
#     source: google-search
#     📄 Dec 2, 2023 ... Given projected spending on clean energy worldwide, that means more than $120 billion could be saved globally by 2030. The United States is ...
#
# ================================================================================
#
# ================================================================================
# 🔍 Fact-checking claim 2/4: The announcement came during a climate summit in Riyadh, where officials also re...
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: SUPPORTS
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: The evidence indicates that an announcement related to net-zero emissions by 2060 was made during a climate-related event in Riyadh. Multiple sources mention a climate summit or conference in Riyadh around October 23, 2021, where Saudi Arabia revealed plans to achieve net-zero emissions by 2060 (e.g., 'The announcement comes days before the COP26 climate change summit ... At the launch of a climate conference in Riyadh, Prince Mohammed ...', 'Saudi Arabia is taking a ... Paving the way to net zero emissions by 2060'). Although one source mentions a plan for 2050, the majority and more recent evidence supports the 2060 target. Therefore, the claim that the announcement came during a climate summit in Riyadh, where officials revealed plans to achieve net-zero emissions by 2060, is supported.
#
# 💭 Explanation:
# The verdict is that the claim is supported. Multiple credible sources confirm that during a climate summit held in Riyadh around October 23, 2021, Saudi officials announced plans to achieve net-zero emissions by 2060. Although there is one mention of a 2050 target, the majority of evidence, including official statements and recent reports, consistently reference the 2060 goal. Therefore, it is reasonable to conclude that the announcement about achieving net-zero emissions by 2060 was made at the Riyadh climate summit.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] HRH the Crown Prince and Prime Minister announces the Kingdom ...
#     🔗 https://www.sgi.gov.sa/knowledge-hub/hrh-the-crown-prince-and-prime-minister-announces-the-kingdom-of-saudi-arabia-s-aims-to-achieve-net-zero-emissions-by-2060/
#     source: google-search
#     📄 Oct 23, 2021 ... ... environment and address climate change challenges while ... net zero emissions by 2060 through the Carbon Circular Economy approach.
#
# [2] Saudi Arabia commits to net zero emissions by 2060
#     🔗 https://www.bbc.com/news/world-middle-east-58955584
#     source: google-search
#     📄 Oct 23, 2021 ... The announcement comes days before the COP26 climate change summit ... At the launch of a climate conference in Riyadh, Prince Mohammed ...
#
# [3] Reducing Carbon Emissions | Saudi Green Initiative Target
#     🔗 https://www.sgi.gov.sa/about-sgi/sgi-targets/reduce-carbon-emissions/
#     source: google-search
#     📄 Paving the way to net zero emissions by 2060. Saudi Arabia is taking a ... Reducing emissions is essential in the fight against climate change. Efforts ...
#
# [4] Top oil exporter Saudi Arabia targets net zero emissions by 2060 ...
#     🔗 https://www.reuters.com/business/cop/saudi-arabia-worlds-biggest-oil-exporter-unveil-green-goals-2021-10-23/
#     source: google-search
#     📄 Oct 24, 2021 ... ... climate change in Riyadh, Saudi Arabia, October 23, 2021. REUTERS ... announced a plan for net zero emissions by 2050. read more. The ...
#
# [5] net zero emissions by 2060
#     🔗 https://www.sgi.gov.sa/saudi-global-climate-impact
#     source: google-search
#     📄 Proactive green initiatives for positive global impact ... Recognizing its responsibility in the fight against climate change, Saudi Arabia has made significant ...
#
# ================================================================================
#
# ================================================================================
# 🔍 Fact-checking claim 3/4: The country, which is currently the world's largest oil producer, aims to divers...
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: SUPPORTS
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: The evidence indicates that Saudi Arabia is currently the world's largest petroleum producer and exporter. Additionally, there are references to the Kingdom's strategy to diversify its energy mix, including boosting gas production, developing nuclear energy, and investing in green hydrogen and solar projects. These points support the claim that the country aims to diversify its energy sources and reduce carbon emissions.
#
# 💭 Explanation:
# The verdict is "supports" because the evidence shows that Saudi Arabia is currently the world's largest oil producer and exporter. Furthermore, the country has outlined strategies to diversify its energy sources by increasing gas production, developing nuclear energy, and investing in green hydrogen and solar power projects. This demonstrates a clear intention to reduce reliance on oil and lower carbon emissions, confirming the claim.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] Energy in Saudi Arabia - Wikipedia
#     🔗 https://en.wikipedia.org/wiki/Energy_in_Saudi_Arabia
#     source: google-search
#     📄 ... oil despite diversification, in particular in the ... For many years the Kingdom of Saudi Arabia has been the world's largest petroleum producer and exporter.
#
# [2] UAE Energy Diversification | UAE Embassy in Washington, DC
#     🔗 https://www.uae-embassy.org/discover-uae/climate-and-energy/uae-energy-diversification
#     source: google-search
#     📄 Carbon Capture: The UAE is pragmatic about the present because even in the swiftest energy transition scenario the world will still need oil. The UAE is the ...
#
# [3] Kingdom of Saudi Arabia Vision 2030
#     🔗 https://www.vision2030.gov.sa/media/rc0b5oy1/saudi_vision203.pdf
#     source: google-search
#     📄 To move from our current position as the 19th largest economy in the ... diversification of the energy mix in the Kingdom. We will also seek to set ...
#
# [4] Sustainable green energy transition in Saudi Arabia: Characterizing ...
#     🔗 https://www.sciencedirect.com/science/article/pii/S2949821X24000668
#     source: google-search
#     📄 " This strategy calls for boosting gas production, diversifying the economy away from oil ... Plans to develop nuclear energy as part of the diversification ...
#
# [5] Canada should diversify oil export markets, country's top oil ...
#     🔗 https://www.reuters.com/business/energy/canadian-natural-resources-reports-fall-fourth-quarter-profit-2025-03-06/
#     source: google-search
#     📄 Mar 6, 2025 ... The company plans to invest approximately C$2 billion ($1.7 billion) into boosting its Mainline pipeline network, which carries crude from ...
#
# ================================================================================
#
# ================================================================================
# 🔍 Fact-checking claim 4/4: The investment will focus on solar and wind power projects across the kingdom....
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: SUPPORTS
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: Multiple pieces of evidence indicate that investments are focusing on solar and wind power projects across the kingdom. For example, the Saudi Green Initiative mentions solar/wind energy connected to the grid, ACWA Power's NEOM project involves various solar and wind projects, and CIP-managed funds focus on investments in offshore and onshore wind and solar PV. Additionally, specific projects like the Dumat Al Jandal Wind Farm and Sakaka Solar Power Plant are cited. This collectively supports the claim that the investment will focus on solar and wind power projects across the kingdom.
#
# 💭 Explanation:
# The verdict supports the claim that the investment will focus on solar and wind power projects across the kingdom. This conclusion is based on multiple sources highlighting significant initiatives such as the Saudi Green Initiative, ACWA Power’s NEOM project, and CIP-managed funds that prioritize solar and wind energy investments. Additionally, specific projects like the Dumat Al Jandal Wind Farm and Sakaka Solar Power Plant demonstrate concrete examples of this focus. Together, these pieces of evidence clearly show that the investment strategy centers on expanding solar and wind power throughout the kingdom.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] Saudi Green Initiative
#     🔗 https://www.vision2030.gov.sa/en/explore/projects/saudi-green-initiative
#     source: google-search
#     📄 Jul 25, 2024 ... Saudi Green Initiative · solar/wind energy was connected to the grid in 2022, providing capacity to power · renewable energy projects are under ...
#
# [2] Reducing Carbon Emissions | Saudi Green Initiative Target
#     🔗 https://www.sgi.gov.sa/about-sgi/sgi-targets/reduce-carbon-emissions/
#     source: google-search
#     📄 AlUla solar energy hubs. (under development). AlUla, Medina Province. 500MW+ ... Wind Project; Solar PV project; green hydrogen facility; carbon capture. One ...
#
# [3] Saudi Vision 2030
#     🔗 https://www.vision2030.gov.sa/en
#     source: google-search
#     📄 Dec 3, 2025 ... Dumat Al Jandal Wind Farm. Sakaka Solar Power Plant. Trojena. Coral Bloom.
#
# [4] Sustainable green energy transition in Saudi Arabia: Characterizing ...
#     🔗 https://www.sciencedirect.com/science/article/pii/S2949821X24000668
#     source: google-search
#     📄 ACWA Power's NEOM project; various solar and wind projects. Focused on ... Multibillion-dollar investment, Solar energy, focusing on industry creation and ...
#
# [5] Renewables & Green Hydrogen: TE H2, CIP, and A.P. Møller Capital ...
#     🔗 https://totalenergies.com/news/press-releases/renewables-green-hydrogen-te-h2-cip-and-ap-moller-capital-partner-large-scale
#     source: google-search
#     📄 Oct 29, 2024 ... The funds managed by CIP focus on investments in offshore and onshore wind, solar PV, biomass and energy-from-waste, transmission and ...
#
# ================================================================================
#
#
# ================================================================================
# 📊 SUMMARY
# ================================================================================
#
# Total claims detected: 4
# Successfully fact-checked: 4
#
# Results by importance:
#   ⚠️ [100%] Saudi Arabia announced plans to invest $100 billion in renew... → NOT_ENOUGH_INFO (90%)
#   ✅ [100%] The announcement came during a climate summit in Riyadh, whe... → SUPPORTS (90%)
#   ✅ [90%] The country, which is currently the world's largest oil prod... → SUPPORTS (90%)
#   ✅ [80%] The investment will focus on solar and wind power projects a... → SUPPORTS (90%)

# %% [markdown]
# ## Quick Examples
#
# You can also use `fact_check_full()` with:
# - **Single claim string**: `await fact_check_full("Saudi Arabia is the largest oil producer")`
# - **Single Claim object**: `await fact_check_full(Claim(id="c1", raw_text="..."))`
# - **Single DetectedClaim**: `await fact_check_full(detected_claims[0])`
# - **Multiple claims**: `await fact_check_full(["Claim 1", "Claim 2", "Claim 3"])`
# - **List of DetectedClaims**: `await fact_check_full(detected_claims)`

# %%
# Fact-check all detected claims automatically!
print("🚀 Single Claim")
results = await fact_check_full("Green tea cures COVID-19 within 48 hours")
    
    # Summary
print("\n" + "=" * 80)
print("📊 SUMMARY")
print("=" * 80)
print(f"Successfully fact-checked: {len(results) if isinstance(results, list) else 1}\n")
# Out:
# 🚀 Single Claim
# ================================================================================
# 🔍 Fact-checking: Green tea cures COVID-19 within 48 hours
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: REFUTES
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: The evidence includes multiple references to false claims about COVID-19 cures, including those involving tea. Specifically, the evidence states that many fake or unproven medical products and methods claim to cure COVID-19, and that claims about treatments such as ivermectin, hydroxychloroquine, and by extension green tea, are false. There is no clear evidence supporting that green tea cures COVID-19 within 48 hours. Instead, the evidence highlights that such claims are false and unproven.
#
# 💭 Explanation:
# The verdict clearly refutes the claim that green tea cures COVID-19 within 48 hours. Multiple reliable sources indicate that there is no scientific evidence supporting green tea as a cure for COVID-19, and many similar claims about unproven treatments have been debunked. While some studies have explored antiviral properties of green tea compounds, these do not translate into an effective or rapid cure, and health authorities warn against relying on such false claims. Therefore, the claim is false because it lacks credible evidence and contradicts established medical understanding.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] List of unproven methods against COVID-19 - Wikipedia
#     🔗 https://en.wikipedia.org/wiki/List_of_unproven_methods_against_COVID-19
#     source: google-search
#     📄 Many fake or unproven medical products and methods claim to diagnose, prevent, or cure COVID-19. Fake medicines sold for COVID-19 may not contain the ...
#
# [2] Coronavirus: Herbal remedies in India and other claims fact-checked
#     🔗 https://www.bbc.com/news/world-asia-india-51910099
#     source: google-search
#     📄 Apr 18, 2020 ... This false claim - shared on social media - refers to the ... treating Covid-19 by giving patients tea. Banner image reading 'more ...
#
# [3] Debunking COVID-19 myths - Mayo Clinic
#     🔗 https://www.mayoclinic.org/diseases-conditions/coronavirus/in-depth/coronavirus-myths/art-20485720
#     source: google-search
#     📄 ... cure COVID-19 (coronavirus disease 2019). If what you heard ... Claims that ivermectin, hydroxychloroquine or chloroquine can treat COVID-19 are false.
#
# [4] 9 Tips to Recover Faster from COVID-19 or Flu
#     🔗 https://www.unitypoint.org/news-and-articles/9-tips-to-recover-faster-from-covid-19-or-flu
#     source: google-search
#     📄 Antivirals are most effective if started within the first 48 hours of symptoms. If used accurately, they can shorten the duration of illness by about 24 ...
#
# [5] Treating mild COVID-19 symptoms at home | HealthPartners Blog
#     🔗 https://www.healthpartners.com/blog/how-to-treat-mild-covid-19-at-home/
#     source: google-search
#     📄 Tests should be performed at least 48 hours apart, and the number of negative ... Studies on green tea and COVID-19 have found the beverage contains a ...
#
# ================================================================================
#
#
# ================================================================================
# 📊 SUMMARY
# ================================================================================
# Successfully fact-checked: 1

# %%
# Fact-check all detected claims automatically!
print("🚀 Single Claim")
results = await fact_check_full("China will ban TikTok in 2026")
    
    # Summary
print("\n" + "=" * 80)
print("📊 SUMMARY")
print("=" * 80)
print(f"Successfully fact-checked: {len(results) if isinstance(results, list) else 1}\n")
# Out:
# 🚀 Single Claim
# ================================================================================
# 🔍 Fact-checking: China will ban TikTok in 2026
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: REFUTES
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: The evidence focuses on the United States banning TikTok or legislating against it, with multiple references to US laws and Supreme Court decisions banning TikTok unless sold by its Chinese parent company ByteDance. There is no mention or indication that China itself will ban TikTok in 2026. In fact, one piece of evidence (Jan 20, 2025) suggests Beijing may be easing its stance on TikTok. Therefore, the claim that China will ban TikTok in 2026 is contradicted by the evidence.
#
# 💭 Explanation:
# The verdict refutes the claim that China will ban TikTok in 2026. The evidence primarily discusses actions taken by the United States, including laws and Supreme Court decisions aimed at banning TikTok unless it is sold by its Chinese parent company, ByteDance. There is no indication that China plans to ban TikTok; in fact, some reports suggest China may be easing its stance on the app. Therefore, the claim that China will ban TikTok in 2026 is not supported by the available information.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] TikTok returns on Apple, Google US app stores as Trump delays ban
#     🔗 https://www.reuters.com/technology/apple-restore-tiktok-us-app-store-after-attorney-generals-letter-bloomberg-news-2025-02-14/
#     source: google-search
#     📄 Feb 13, 2025 ... President Trump delayed a ban on the Chinese-owned social media app ... 'Battlefield' maker EA forecasts softer 2026 bookings amid slow spending, ...
#
# [2] Trump TikTok deal: Who might own the app and how would it work?
#     🔗 https://www.bbc.com/news/articles/clyng762q4eo
#     source: google-search
#     📄 Sep 30, 2025 ... US politicians passed a law in 2024 banning the app in the country unless it was sold by its Chinese parent company ByteDance. Neither ByteDance ...
#
# [3] TikTok prepares to shut down app in US on Sunday, sources say ...
#     🔗 https://www.reuters.com/technology/tiktok-preparing-us-shut-off-sunday-information-reports-2025-01-15/
#     source: google-search
#     📄 Jan 15, 2025 ... Supreme Court to decide on TikTok ban by Sunday; TikTok plans data ... TikTok and its Chinese parent, ByteDance, did not immediately ...
#
# [4] Trump issues executive order to suspend TikTok ban. But can it stick ...
#     🔗 https://apnews.com/article/trump-tiktok-ban-executive-order-50df1f96c25576762b65e24b63ce61eb
#     source: google-search
#     📄 Jan 20, 2025 ... Although ByteDance spent months repeating it wasn't interested in selling, Beijing on Monday also signaled a possible easing on China's stance ...
#
# [5] Opinion | It's September 2026, and the Pentagon Is Alarmed - The ...
#     🔗 https://www.nytimes.com/2025/01/09/opinion/tiktok-supreme-court-china.html
#     source: google-search
#     📄 Jan 9, 2025 ... The effort to ban TikTok is not about what's on the platform but about who runs it ... There's reason to believe China is already using TikTok ...
#
# ================================================================================
#
#
# ================================================================================
# 📊 SUMMARY
# ================================================================================
# Successfully fact-checked: 1

# %%
# Fact-check all detected claims automatically!
print("🚀 Single Claim")
results = await fact_check_full("Saudi Arabia is currently the world's largest oil producer")
    
    # Summary
print("\n" + "=" * 80)
print("📊 SUMMARY")
print("=" * 80)
print(f"Successfully fact-checked: {len(results) if isinstance(results, list) else 1}\n")
# Out:
# 🚀 Single Claim
# ================================================================================
# 🔍 Fact-checking: Saudi Arabia is currently the world's largest oil producer
# ================================================================================
#
# ⏳ Processing... This may take 30-60 seconds...
#
# ================================================================================
# ✅ RESULTS
# ================================================================================
#
# 📊 Verdict: REFUTES
# 🎯 Confidence: 90%
#
# 🧠 Reasoning: The evidence indicates that Saudi Arabia is among the top oil producers but not the largest. For example, one source lists Saudi Arabia at 11.13 million barrels per day and Russia at 10.75 million barrels per day, suggesting Saudi Arabia is close but not definitively the largest. Another source mentions the US, Saudi Arabia, Russia, and Canada as top producers without clearly stating Saudi Arabia is the largest. Additionally, the evidence notes Saudi Arabia's production declined in 2023, which further undermines the claim that it is currently the world's largest producer. Therefore, the claim that Saudi Arabia is currently the world's largest oil producer is not clearly supported and is effectively refuted by the evidence showing multiple top producers and no clear dominance by Saudi Arabia.
#
# 💭 Explanation:
# The verdict refutes the claim that Saudi Arabia is currently the world's largest oil producer. Evidence shows that while Saudi Arabia is one of the top producers, its output is close to but not definitively higher than that of Russia and the United States, with reported production figures around 11 million barrels per day, similar to Russia's 10.75 million barrels per day. Additionally, Saudi Arabia's oil production declined in 2023, indicating it does not hold a clear lead. Therefore, the claim is not supported because multiple countries produce comparable amounts of oil, and Saudi Arabia is not clearly the largest producer at this time.
#
# 📚 Evidence (10 snippet(s)):
# --------------------------------------------------------------------------------
#
# [1] List of countries by oil extraction - Wikipedia
#     🔗 https://en.wikipedia.org/wiki/List_of_countries_by_oil_extraction
#     source: google-search
#     📄 supply and demand In addition to being top 5 in oil production, the United ... Saudi Arabia (OPEC), 10,815,700, Asia · Russia (OPEC+), 10,750,000, Asia ...
#
# [2] What countries are the top producers and consumers of oil?
#     🔗 https://www.eia.gov/tools/faqs/faq.php?id=709&t=6
#     source: google-search
#     📄 Saudi Arabia, 11.13, 11%. Russia, 10.75, 11%. Canada, 5.76, 6%. China, 5.26, 5%. Iraq ... oil (petroleum and other liquids) production, as of April 11, 2024. The ...
#
# [3] Saudi Aramco - Wikipedia
#     🔗 https://en.wikipedia.org/wiki/Saudi_Aramco
#     source: google-search
#     📄 ... petroleum and natural gas company that is the national oil company of Saudi Arabia. As of 2024, it is the fourth-largest company in the ...
#
# [4] 10 Top Oil-producing Countries | INN
#     🔗 https://investingnews.com/daily/resource-investing/energy-investing/oil-and-gas-investing/top-oil-producing-countries/
#     source: google-search
#     📄 Oct 29, 2024 ... The top oil production by country includes the US, Saudi Arabia, Russia and Canada. Global production was 101.8 million bpd.
#
# [5] Saudi Aramco: the oil colossus | Reuters
#     🔗 https://www.reuters.com/business/energy/saudi-aramco-oil-colossus-2024-05-30/
#     source: google-search
#     📄 May 30, 2024 ... ... Saudi Arabia, January 12, 2024. REUTERS ... Eight years later, the Saudi Arabian Oil Company (Saudi Aramco) was officially established.
#
# ================================================================================
#
#
# ================================================================================
# 📊 SUMMARY
# ================================================================================
# Successfully fact-checked: 1
